# %% [markdown]
# ---
#
# Universidade Federal do Rio Grande do Norte
#
# Centro de Tecnologia
#
# Departamento de Engenharia Elétrica
#
# ELE0605 - Controladores Lógicos Programáveis
#
# Discente: Levy Gabriel
#
#
# ---

# %% [markdown]
# # Exercícios - Aula 06: Mapas de Karnaugh

# %% [markdown]
# #### Questão 1

# %% [markdown]
# - Tabela-verdade

# %% [markdown]
# ![CLP_aula06.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Mapa de Karnaugh

# %% [markdown]
# ![CLP_aula061.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Equação simplificada pelo mapa de Karnaugh

# %% [markdown]
# $Y = CLD \cdot (SJ+SP)$

# %% [markdown]
# - Diagrama em linguagem Ladder

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Questão 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### (a):

# %% [markdown]
# - Equação não simplificada

# %% [markdown]
# $L = A\cdot B + C \cdot B + \bar{B} \cdot C$

# %% [markdown]
# - Tabela-verdade

# %% [markdown]
# ![CLP_aula06.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Mapa de Karnaugh

# %% [markdown]
# ![CLP_aula06.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Equação simplificada pelo mapa de Karnaugh

# %% [markdown]
# $L = A \cdot B + \bar{A} \cdot C$

# %% [markdown]
# - Diagrama em linguagem Ladder

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### (b):

# %% [markdown]
# - Equação não simplificada

# %% [markdown]
# $L = A + A\cdot \bar{B} + B \cdot \bar{A}$

# %% [markdown]
# - Tabela-verdade

# %% [markdown]
# ![CLP_aula061.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Mapa de Karnaugh

# %% [markdown]
# ![CLP_aula061.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Equação simplificada pelo mapa de Karnaugh

# %% [markdown]
# $L = A + B$

# %% [markdown]
# - Diagrama em linguagem Ladder

# %% [markdown]
# ![image.png](data:image/png;base64,...)
