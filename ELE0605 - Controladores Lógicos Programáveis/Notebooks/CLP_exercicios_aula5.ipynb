# %% [markdown]
# ---
#
# Universidade Federal do Rio Grande do Norte
#
# Centro de Tecnologia
#
# Departamento de Engenharia Elétrica
#
# ELE0605 - Controladores Lógicos Programáveis
#
# Discente: Levy Gabriel
#
#
# ---

# %% [markdown]
# # Exercícios - Aula 05: Circuitos Combinacionais

# %% [markdown]
# #### Questão 1

# %% [markdown]
# A primeira questão solicita que equações de lógica combinacional sejam expressas como programas em lógica Ladder:

# %% [markdown]
# ###### (a) $Y = (A+B) \cdot C \cdot D$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### (b) $Y = A \cdot \bar{B} \cdot C + \bar{D} + E$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### (c) $Y = [(\bar{A}+\bar{B}) \cdot C] + D \cdot E$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### (d) $Y = (\bar{A} \cdot B \cdot \bar{C}) + (D \cdot \bar{E} \cdot F)$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Questão 2

# %% [markdown]
# Esta questão informa que três chaves (A, B e C) devem estar **simultaneamente ligadas ou desligadas** para que uma lâmpada (L) seja **energizada**. Para isso deve ser determinada a equação em lógica combinacional para esse sistema e, em seguida o diagrama Ladder correspondente.

# %% [markdown]
# Assim, sua equação lógica será:
#
# \begin{align}
# L = (A \cdot B \cdot C) + (\bar{A} \cdot \bar{B} \cdot \bar{C})
# \end{align}

# %% [markdown]
# ![image.png](data:image/png;base64,...)
