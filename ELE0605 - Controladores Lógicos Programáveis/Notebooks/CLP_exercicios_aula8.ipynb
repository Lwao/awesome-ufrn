# %% [markdown]
# ---
#
# Universidade Federal do Rio Grande do Norte
#
# Centro de Tecnologia
#
# Departamento de Engenharia Elétrica
#
# ELE0605 - Controladores Lógicos Programáveis
#
# Discente: Levy Gabriel
#
#
# ---

# %% [markdown]
# # Exercícios - Aula 08: Sistemas sequenciais

# %% [markdown]
# #### Questão 1

# %% [markdown]
# ![CLP-aula08-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### Questão 2

# %% [markdown]
# ![CLP-aula08-2.jpg](data:image/jpeg;base64,...)
