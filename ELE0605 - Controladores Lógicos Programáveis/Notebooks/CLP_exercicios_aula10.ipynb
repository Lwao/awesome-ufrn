# %% [markdown]
# ---
#
# Universidade Federal do Rio Grande do Norte
#
# Centro de Tecnologia
#
# Departamento de Engenharia Elétrica
#
# ELE0605 - Controladores Lógicos Programáveis
#
# Discente: Levy Gabriel
#
#
# ---

# %% [markdown]
# # Exercícios - Aula 10: Lista de instruções

# %% [markdown]
# #### Questão 1

# %% [markdown]
# - Equação booleana: $L = A \cdot (\bar{B}+C) + B \cdot D$

# %% [markdown]
# - Diagrama Ladder:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Lista de instruções:

# %% [markdown]
# ```
# LD     A
# AND(
# LDN    B
# OR     C
# )
# OR(
# LD     B
# AND    D
# )
# ST     L
# ```

# %% [markdown]
# #### Questão 2

# %% [markdown]
# - Lista de instruções:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Diagrama Ladder:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
